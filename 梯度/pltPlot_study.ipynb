# %% [markdown]
# # **一、Pyplot简介**
# - Pyplot 是 Matplotlib 的子库，提供了和 MATLAB 类似的绘图 API。
#
# - Pyplot 是常用的绘图模块，能很方便让用户绘制 2D 图表。
#
# - Pyplot 包含一系列绘图函数的相关函数，每个函数会对当前的图像进行一些修改，例如：给图像加上标记，生成新的图像，在图像中产生新的绘图区域等等。

# %% [markdown]
# # **二、Pyplot导入**
# 我们可以使用 import 导入 pyplot 库，并设置一个别名 plt：

# %% [markdown]
# >```python
# >   from matplotlib import pyplot as plt
# >```

# %% [markdown]
# 这样我们就可以使用 plt 来引用 pyplot 包的方法

# %% [markdown]
# # **三、Pyplot绘图**
# `plt.figure`的作用是定义一个大的图纸，可以设置图纸的大小、分辨率等，例如:
# > fig = plt.figure(figsize=(16, 16), dpi=300)  # 初始化一张画布
#
# ## **3.1 折线图**

# %%
from matplotlib import pyplot as plt
import numpy as np

xpoints=np.array([0,10]) 
ypoints=np.array([0,100])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# 我们通过两个点(0,0)和(10,100)绘制出折线图，x轴的点坐标就是0和10，y轴的点坐标就是0,100。分别将x轴的点和y轴的点存放到数组中，再调用plot画在画布上，最后show显示出来就搞定了。

# %% [markdown]
# ## **3.2 熟悉plot()函数**
# plot() 用于画图它可以绘制点和线，语法格式如下：
#
# >```python
# >    #画单条线
# >    plot([x], y, [fmt], *, data=None, **kwargs)
# >    #画多条线
# >    plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
# >```

# %% [markdown]
# - **x, y：** 点或线的节点，x 为 x 轴数据，y 为 y 轴数据，数据可以列表或数组。
# - **fmt：** 可选，定义基本格式（如颜色、标记和线条样式）。
# - **\*\*kwargs：** 可选，用在二维平面图上，设置指定属性，如标签，线的宽度等

# %% [markdown]
# **颜色字符：** ‘b’ 蓝色，‘m’ 洋红色，‘g’ 绿色，‘y’ 黄色，‘r’ 红色，‘k’ 黑色，‘w’ 白色，‘c’ 青绿色，‘#008000’ RGB 颜色符串。多条曲线不指定颜色时，会自动选择不同颜色。
# **线条样式：** ‘‐’ 实线，‘‐‐’ 破折线，‘‐.’ 点划线，‘:’ 虚线。
# **标记字符：** ‘.’ 点标记，‘,’ 像素标记(极小点)，‘o’ 实心圈标记，‘v’ 倒三角标记，‘^’ 上三角标记，‘>’ 右三角标记，‘<’ 左三角标记 等等。

# %% [markdown]
# >纸上得来终觉浅，绝知此事要躬行，大家看下面几个实例就明白了。

# %% [markdown]
# **例1：**
# 我们可以绘制任意数量的点，只需确保两个<font color="#dd0000">轴上的点数</font>相同即可。绘制一条不规则线，坐标为 (1, 3) 、 (2, 8) 、(6, 1) 、(8, 10)，对应的两个数组为：[1, 2, 6, 8] 与 [3, 8, 1, 10]。

# %% [markdown]
# 可以看到plot中多了个参数'r--o'，它其实就是刚刚的[fmt]，分别代表了颜色字符r，线条样式–，标记字符o，<font face="微软雅黑" size=3 color=#FF0000 ><b>这三者的顺序随意，个数随意</b></font>，非常方便。
# 我们给线条变成红色，并且线条样式为虚线，再让每个点都被‘o’符号标记

# %%
from matplotlib import pyplot as plt
import numpy as np

xpoints=np.array([1, 2, 6, 8])
ypoints=np.array([3, 8, 1, 10])
plt.plot(xpoints,ypoints,'r--o')
plt.show()

# %% [markdown]
# 这里参数改成了'.g-.'，可以得知引号中第一个参数是符号标记‘.’ ; 第二个是颜色字符g ; 第三个是线条样式-. 。这样就变成了绿色的点划线，并且点都被标记出来了。

# %%
from matplotlib import pyplot as plt
import numpy as np

xpoints=np.array([1, 2, 6, 8])
ypoints=np.array([3, 8, 1, 10])

# 线条样式：‘‐’ 实线，‘‐‐’ 破折线，‘‐.’ 点划线，‘:’ 虚线。
plt.plot(xpoints,ypoints,'xg-.') 
plt.show()

# %% [markdown]
# 如果我们不指定 x 轴上的点，则 x 会根据 y 的值来设置为 0, 1, 2, 3…N-1。
#
# 从下图可以看出 x 的值默认设置为 [0, 1, 2, 3, 4]。

# %%
from matplotlib import pyplot as plt
import numpy as np

ypoints=np.array([2, 6, 2, 6,2])
# 线条样式：‘‐’ 实线，‘‐‐’ 破折线，‘‐.’ 点划线，‘:’ 虚线。
plt.plot(ypoints,'.c:')
plt.show()

# %% [markdown]
# ## **3.3 轴标签和标题**
# 我们可以使用 xlabel() 和 ylabel() 方法来设置 x 轴和 y 轴的标签。
# 我们可以使用 title() 方法来设置标题。
# 如果我们想使用中文显示标题和标签，只需要加入一行`plt.rcParams['font.family']=['STFangsong']`，这样就可以使用系统字体中的“仿宋”。

# %%
from matplotlib import pyplot as plt
import numpy as np

xpoints=np.array([1,2,3,4,5])
ypoints=np.array([5,3,8,5,9])

plt.rcParams['font.family']=['STFangsong']

plt.plot(ypoints,'oc-')
plt.xlabel('x-label')
plt.ylabel('y-label标签')
plt.title('picture')


plt.show()

# %% [markdown]
# 此外我们还可以自定义字体的样式：用size设置字体大小；color设置字体颜色，可以缩写，可以完整写，也可以用rgb十六进制写。

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.rcParams['font.family']=['STFangsong']
xpoints=np.array([1,2,3,4,5])
ypoints=np.array([5,3,8,5,9])
plt.plot(ypoints,'oc-')
plt.title('折线图',size='30',color='#ABCDEF')
plt.xlabel('数量',size='15',color='blue')
plt.ylabel('价格',size='20',color='m')
plt.show()

# %% [markdown]
# 最后，我们可以修改标题与标签的定位：

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.rcParams['font.family']=['STFangsong']
xpoints=np.array([1,2,3,4,5])
ypoints=np.array([5,3,8,5,9])
plt.plot(ypoints,'oc-')
plt.title('折线图',loc='right',size='30',color='#409882')
plt.xlabel('数量',loc='left',size='15',color='blue')
plt.ylabel('价格',loc='top',size='20',color='m')
plt.show()

# %% [markdown]
# title() 方法提供了 loc 参数来设置标题显示的位置，可以设置为: ‘left’, ‘right’, 和 ‘center’， 默认值为 ‘center’。
#
# xlabel() 方法提供了 loc 参数来设置 x 轴显示的位置，可以设置为: ‘left’, ‘right’, 和 ‘center’， 默认值为 ‘center’。
#
# ylabel() 方法提供了 loc 参数来设置 y 轴显示的位置，可以设置为: ‘bottom’, ‘top’, 和 ‘center’， 默认值为 ‘center’。

# %% [markdown]
# ## **3.4 绘制多图**
#
# 我们可以使用 pyplot 中的 subplot() 和 subplots() 两种方法来绘制多个子图。
#
# - **plt.subplot() 方法在绘图时需要指定位置，后续直接调用plt**
# >```python
# >import pandas as pd
# >import matplotlib.pyplot as plt
# >import numpy as np
# ># 创建1x2x3的三维数组
# >img = np.array([[[1, 2, 3,4,5,6,5], [4, 5, 4,2, 3,4,5]], [[6, 4, 6,8, 3,9,5], [5, 4, 6,2, 5,6,2]]])
# >print(img[0])
# >print(img[1])
# ># fig = plt.figure(figsize=(12, 4), dpi=200)
# >for i in range(len(img)):
# >    plt.subplot(1, len(img), i + 1)
# >    plt.imshow(img[i])
# >plt.show()
#
#
#     plt.subplot作用是指定子图的位置，比如说现在总共有1行10列，当前子图位于哪里；使用这个函数时需要先定义一个大的图纸，因为subplot函数无法更改图纸的大小和分辨率等信息。后续直接调用plt，获取当前活跃的图层。
#
# - **plt.subplots() 方法可以一次生成多个，在调用时只需要调用生成对象的 ax 即可。**
# >```python
# >import matplotlib.pyplot as plt
# >import numpy as np
# ># 创建1x2x3的三维数组
# >img = np.array([[[1, 2, 3, 4, 5, 6, 5], [4, 5, 4, 2, 3, 4, 5]], [[6, 4, 6, 8, 3, 9, 5], [5, 4, 6, 2, 5, 6, 2]]])
# >print(img[0])
# >print(img[1])
# >fig, ax = plt.subplots(1, len(img), figsize=(15, 10))
# >for i in range(len(img)):
# >    ax[i].imshow(img[i])
# >plt.show()
#
#
#    使用plt.subplots函数时，可以直接在该函数内部设置子图纸信息。该函数返回两个变量，一个是Figure实例fig，另一个 AxesSubplot实例ax 。fig代表整个图像，ax代表坐标轴和画的子图，通过下标获取需要的子区域。后续我们需要对子图操作时，直接ax[i].imshow(img[i])就行.

# %% [markdown]
# - **subplots与subplot的区别在于：**（1）不需要通过plt来操作图层，每一个图层都有指定的axes；（2）一个写在for循环外面，一个写在里面；归根于原因还是suplots绘制多少图已经指定了，所以ax提前已经准备好了，而subplot函数调用一次就绘制一次，没有指定。
#
#   **subplot和subplots都可以实现画子图功能**，只不过subplots帮我们把画板规划好了，返回一个坐标数组对象，而subplot每次只能返回一个坐标对象，subplots还可以直接指定画板的大小。
#
#   **坐标轴修改：** plt在修改坐标时直接写plt.xlabel();plt.ylabel();plt.xlim();plt.ylim()等等就行，但是axes和plt不一样，axes需要加上set，例如：axes.set_xlabel();axes.set_xlim() 这一点需要格外注意。
#   对于修改子图的坐标轴信息，很明显是subplots更方便，因为他有独立的axes，更方便让每一个子图的坐标轴不同。

# %%
#例如axes更改坐标轴信息：
import matplotlib.pyplot as plt
import numpy as np
# 创建1x2x3的三维数组
img = np.array([[[1, 2, 3, 4, 5, 6, 5], [4, 5, 4, 2, 3, 4, 5]], [[6, 4, 6, 8, 3, 9, 5], [5, 4, 6, 2, 5, 6, 2]]])
print(img[0])
print(img[1])
fig, ax = plt.subplots(1, len(img), figsize=(15, 10))
for i in range(len(img)):
    ax[i].imshow(img[i])
    ax[i].set_xlabel("test csdn{0}".format(i))
plt.show()
# Out:
# [[1 2 3 4 5 6 5]
#  [4 5 4 2 3 4 5]]
# [[6 4 6 8 3 9 5]
#  [5 4 6 2 5 6 2]]

# %%
# 例如plt修改坐标轴信息
import matplotlib.pyplot as plt
import numpy as np
# 创建1x2x3的三维数组
img = np.array([[[1, 2, 3, 4, 5, 6, 5], [4, 5, 4, 2, 3, 4, 5]], [[6, 4, 6, 8, 3, 9, 5], [5, 4, 6, 2, 5, 6, 2]]])
print(img[0])
print(img[1])
fig = plt.figure(figsize=(12, 4), dpi=200)
for i in range(len(img)):
    plt.subplot(1, len(img),i+1)
    plt.imshow(img[i])
    plt.xlabel(f"csdn test{i}")
plt.show()
# Out:
# [[1 2 3 4 5 6 5]
#  [4 5 4 2 3 4 5]]
# [[6 4 6 8 3 9 5]
#  [5 4 6 2 5 6 2]]

# %% [markdown]
# ### **3.4.1 subplot函数的语法格式：subplot(nrows, ncols, index)**
#
# subplot( )将整个绘图区域分成 nrows 行和 ncols 列，然后从左到右，从上到下的顺序对每个子区域进行编号 1…N ，左上的子区域的编号为 1、右下的区域编号为 N，编号可以通过参数 index 来设置。

# %%
from matplotlib import pyplot as plt
import numpy as np
#plot1
xpoints=np.array([0,2,4,6,8])
ypoints=np.array([0,3,6,9,12])
plt.subplot(1,2,1)   #subplot(nrows, ncols, index)
plt.plot(xpoints,ypoints)
plt.xlabel('x')
plt.ylabel('y')
plt.title('plot1')

#plot2
x=np.array([1,3,5,8])
y=np.array([10,3,6,2])
plt.subplot(1,2,2)  #subplot(nrows, ncols, index)
plt.plot(x,y)
plt.title('plot2',color='m')

plt.show()

# %% [markdown]
# 可以看到plot1和plot2在用plot前都加上了plt.subplot(1,2,1)和plt.subplot(1,2,2)，意思是说将**画布分为一行两列，左边标号是1，右边标号是2**，所以plot1就在左图位置，plot2就画在右图位置。就这么简单。

# %% [markdown]
# - 如果我们只在第一块区域画图，将plot2代码删去，运行一下。可以看到只有plot1在画布的左侧，右侧没有图像，所以显示为空。
# >```python
# >from matplotlib import pyplot as plt
# >import numpy as np
# >#plot1
# >xpoints=np.array([0,2,4,6,8])
# >ypoints=np.array([0,3,6,9,12])
# >plt.subplot(1,2,1)
# >plt.plot(xpoints,ypoints)
# >plt.xlabel('x')
# >plt.ylabel('y')
# >plt.title('plot1')
# >plt.show()
# ```

# %% [markdown]
# ![image.png](attachment:f663d050-1d67-4e65-a714-d5ee0508fd7b.png)

# %% [markdown]
# ### **3.4.2 subplots函数的语法格式：subplots(nrows, ncols)：**
# > ```python
# >matplotlib.pyplot.subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True, width_ratios=None, height_ratios=None, subplot_kw=None, gridspec_kw=None, **fig_kw)
# > ```
#
# plt.subplots()返回一个包含figure和axes对象的元组，通常可以将其分解为fig和ax两个变量。
# 例如：
# > fig, ax = plt.subplots()
#
# 在这个例子中，**fig是整个图形，ax是子图**。
# **参数：**
# - nrows：图表的行数，默认为 1
# - ncols：图表的列数，默认为 1
# - sharex、sharey：设置 x、y 轴共享属性，默认为 False，可设置为‘True’。 False即 每个子图的 x 轴或 y 轴独立；True 即所有子图共享 x 轴或y 轴
# - subplot_kw：向每个子图传递一个字典，这个字典包含了创建子图时想要应用的额外关键字参数
# - gridspec_kw：调整子图之间的水平间距、垂直间距等布局相关的选项。
#
# **Returns:**
# - fig：Figure
# - ax：Axes or array of Axes。ax可以是单个Axes对象，如果创建了多个子图，则可以是Axes对象的数组。
#
# 具体方法有两种：

# %% [markdown]
# #### （1）**通过ax控制子图**
#
# 1. 单行单列
# 我们可以通过在plt.subplots()中指定参数nrows和ncols来创建单行单列的子图。
# 例如：
# > fig, ax = plt.subplots(nrows=1, ncols=2)
#
# 在这个例子中，我们创建了一个包含两个子图的图形，每个子图都在一行中。
#
# 2. 多行多列
# 我们可以通过在plt.subplots()中指定参数nrows和ncols来创建多行多列的子图。例如：
# > fig, ax = plt.subplots(nrows=2, ncols=2)
#
# 在这个例子中，我们创建了一个包含四个子图的图形，每个子图都有自己的行和列。
#
#
# #### （2）**通过plt控制子图**
# 除了通过ax控制子图外，我们还可以通过plt来控制子图。
# 例如：
# >p1, p2 = plt.subplots(1, 2)
#
# 在这个例子中，我们创建了一个包含两个子图的图形，每个子图都在一行中。p1和p2分别表示两个子图的plot对象，可以通过它们来进一步操作子图。
#
# 我们还是通过绘制图的例子，来更直观的感受一下:

# %%
# using the variable ax for single a Axes
fig, ax = plt.subplots()

# using the variable axs for multiple Axes
fig, axs = plt.subplots(2, 2)

# using tuple unpacking for multiple Axes
fig, (ax1, ax2) = plt.subplots(1, 2)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
 
x1 = np.linspace(0,100,400)
x2 = np.linspace(0,50,400)
y11 = 2*x1
y12=x1**2
y21=2/(x2+1)
y22=np.sin(x2)
f, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2)
ax1.plot(x1, y11)
ax1.set_title('11')
 
ax2.plot(x1, y12)
ax2.set_title('12')
 
ax3.plot(x2, y21)
ax3.set_title('21')
 
ax4.plot(x2, y22)
ax4.set_title('22')
 
plt.show()

# %% [markdown]
# **share参数**
# 更改sharex=True，可以看到第二行的x轴范围扩大到与第一行相同

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
 
x1 = np.linspace(0,100,400)
x2 = np.linspace(0,50,400)
y11 = 2*x1
y12 = x1**2
y21 = 2/(x2+1)
y22 = np.sin(x2)
f, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2,sharex = True)
ax1.plot(x1, y11)
ax1.set_title('11')
 
ax2.plot(x1, y12)
ax2.set_title('12')
 
ax3.plot(x2, y21)
ax3.set_title('21')
 
ax4.plot(x2, y22)
ax4.set_title('22')
 
plt.show()

# %% [markdown]
# **subplot_kw**
# 增加subplot_kw={'facecolor': 'grey'}，可以看到子图背景（facecolor）更换为灰色。
#
# **gridspec_kw**
# 增加gridspec_kw={'hspace': 1, 'wspace': 1}，可以看到子图间距变大

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.linspace(0, 100, 400)
x2 = np.linspace(0, 50, 400)
y11 = 2 * x1
y12 = x1 ** 2
y21 = 2 / (x2 + 1)
y22 = np.sin(x2)
f, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, sharex=True, subplot_kw={'facecolor': 'grey'},
                                           gridspec_kw={'hspace': 1, 'wspace': 1})
ax1.plot(x1, y11)
ax1.set_title('11')

ax2.plot(x1, y12)
ax2.set_title('12')

ax3.plot(x2, y21)
ax3.set_title('21')

ax4.plot(x2, y22)
ax4.set_title('22')

plt.show()

# %% [markdown]
# ## **3.5绘制散点图**
# 我们可以使用 pyplot 中的 scatter() 方法来绘制散点图，具体格式参考[官方文档链接](https://matplotlib.org/3.7.2/api/_as_gen/matplotlib.pyplot.plot.html)。
#
# scatter() 方法语法格式如下:
# >```python
# >matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)
# >```

# %% [markdown]
# 功能：A scatter plot of y vs. x with varying marker size and/or color.参数：
# - x，y：长度相同的数组，也就是我们即将绘制散点图的数据点，输入数据。
# - s：点的大小，默认 20，也可以是个数组，数组每个参数为对应点的大小。
# - c：点的颜色，默认蓝色 ‘b’，也可以是个 RGB 或 RGBA 二维行数组。
# - marker：点的样式，默认小圆圈 ‘o’。
# - cmap：Colormap，颜色条，默认为'viridis'，一个colormap的名字，只有 c 是一个浮点数数组的时才使用。
# - norm：Normalize，默认 None，数据亮度在 0-1 之间，只有 c 是一个浮点数的数组的时才使用。
# - vmin，vmax：亮度设置，在 norm 参数存在时会忽略。
# - alpha：透明度设置，0-1 之间，默认 None，即不透明。
# - linewidths：标记点的长度。

# %% [markdown]
# **（1） 我们在画布上绘制下这8个点：**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([1, 4, 9, 16, 7, 11, 23, 18])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# **（2）我们来设置散点的大小、颜色：**
# - 设置参数s，通过定义一个sizes数组，数组元素就是每个点的大小；
# - 设置参数c，我们还可以通过定义colors数组，设置点的颜色；

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([1, 4, 9, 16, 7, 11, 23, 18])
# 大小
sizes = np.array([20,50,100,200,500,1000,200,100])
# 颜色
colors = np.array(["red","green","black","orange","purple","beige","cyan","magenta"])
plt.scatter(x, y,sizes=sizes,c=colors)
plt.show()

# %% [markdown]
# **（3）我们来设置散点图的颜色条：**
# Matplotlib 模块提供了很多可用的颜色条。颜色条就像一个颜色列表，其中每种颜色都有一个范围从 0 到 100 的值。
# 设置颜色条需要使用 cmap 参数，默认值为 ‘viridis’，之后颜色值设置为 0 到 100 的数组。如果要显示颜色条，需要使用 plt.colorbar() 方法：

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([1, 4, 9, 16, 7, 11, 23, 18])
sizes = np.array([20,50,100,200,500,1000,200,100])
# c为数组，cmap才有意义
colors = np.array([10, 20, 30, 40, 50, 60, 70, 80])
plt.scatter(x, y,sizes=sizes,c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ## **3.6保存和导出图形**
# 创建完图形后，我们通常需要保存或导出它们以便在其他地方使用。Matplotlib 提供了多种保存图形的方法：

# %%
import matplotlib.pyplot as plt
import numpy as np

# 创建一个简单的图形
fig, ax = plt.subplots(figsize=(8, 6))
x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x))
ax.set_title('Sine Wave - how2matplotlib.com')

# 保存为 PNG 文件
plt.savefig('sine_wave.png', dpi=300, bbox_inches='tight')

# 保存为 PDF 文件
plt.savefig('sine_wave.pdf', bbox_inches='tight')

# 保存为 SVG 文件
plt.savefig('sine_wave.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# # **四、Pyplot经典例子：**
# ## 4.1屏蔽散点图
# 屏蔽一些数据点，并添加一条线来标记遮盖区域。

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
# 这句的意思是:area1是所有r值小于r0对应序号的area的集合
area1 = np.ma.masked_where(r < r0, area)
# 这句的意思是:area1是所有r值大于等于r0对应序号的area的集合
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %% [markdown]
# area、area1、area2 和r、r0的变量值。
# ![image.png](attachment:138cd516-ebc7-469e-af86-393feadbaa8a.png)

# %% [markdown]
# ## **4.2填充曲线间区域 ax2.fill_between()**
# 参数y1和y2可以是标量，表示给定y值处的水平边界。如果只给出y1，y2默认为0。

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2 * np.pi * x)
y2 = 0.8 * np.sin(4 * np.pi * x)

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(6, 6))
# y1到y2的曲线区域，y2默认为0
ax1.fill_between(x, y1)
ax1.set_title('fill between y1 and 0')

ax2.fill_between(x, y1, 1)
ax2.set_title('fill between y1 and 1')

ax3.fill_between(x, y1, y2)
ax3.set_title('fill between y1 and y2')
ax3.set_xlabel('x')
fig.tight_layout()

plt.show()

# %% [markdown]
# ## **4.3置信区间 ax2.fill_between()**
# fill_between的一个常见应用是表示置信区间带。
# fill_between使用颜色循环中的颜色作为填充颜色。当应用于填充区域时，这些颜色可能有点过于强烈。因此，通常通过使用alpha值使区域半透明来减轻颜色是一种好的做法。

# %%
import matplotlib.pyplot as plt
import numpy as np

N = 21
x = np.linspace(0, 10, 11)
y = [3.9, 4.4, 10.8, 10.3, 11.2, 13.1, 14.1, 9.9, 13.9, 15.1, 12.5]

# fit a linear curve and estimate its y-values and their error.
a, b = np.polyfit(x, y, deg=1)
y_est = a * x + b
y_err = x.std() * np.sqrt(1 / len(x) +
                          (x - x.mean()) ** 2 / np.sum((x - x.mean()) ** 2))

fig, ax = plt.subplots()
ax.plot(x, y_est, '-')
ax.fill_between(x, y_est - y_err, y_est + y_err, alpha=0.2)
ax.plot(x, y, 'o', color='tab:brown')

plt.show()
